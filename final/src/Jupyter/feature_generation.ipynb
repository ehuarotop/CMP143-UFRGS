# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.optimize import curve_fit
import csv
import pandas as pd
import sys
#import statsmodels.api as sm
np.set_printoptions(threshold=sys.maxsize)
csv.field_size_limit(sys.maxsize)

base_dir = "/home/ehuarotop/Documents/Computer_Science/UFRGS/"

#PATH_DIR = "../../projeto-geodigital/FigurasAnotadas01"
#PATH_DIR = "../../jupyter-notebooks/projeto-geodigital/Imagems_de_PDFs"
#PATH_DIR = base_dir + "projeto-geodigital/platos_comida"
#PATH_DIR = base_dir + "projeto-geodigital/Dataset-BG-Petrobras/img_from_google_francisco/petrobras"
PATH_DIR = "image_dataset_5"

# TODO: verify parameter 'img' (should be 'file'?)
def get_histogram(file, abs_value=False, downsample=1):
    print(file)
    #reading the image into an mxnx3 array
    img = cv.imread(file)

    #getting pixel values in float32
    img = img.astype(np.float32)

    #splitting color channels
    b,g,r = cv.split(img)
    #merging them in RGB order.
    img_orig = cv.merge((r,g,b))
    
    #Calculating the 3D histogram of cores:
    rows,cols,channels = img_orig.shape
    img_vector = np.reshape(img_orig, (rows*cols,channels))
    img_hist3d = np.histogramdd(img_vector, bins=5)
    img_norm_hist3d = img_hist3d[0] / np.max(img_hist3d[0])
    i,j,k = img_norm_hist3d.shape
    img_norm_hist3d_feature_vector = np.array(np.reshape(img_norm_hist3d,  i*j*k))

    #defining the filter operator
    gfilter = np.matrix(('1.0 -1.0'))

    #applying filter to each matrix separately (image derivative)
    b = cv.filter2D(b, -1, gfilter)
    g = cv.filter2D(g, -1, gfilter)
    r = cv.filter2D(r, -1, gfilter)
    
    #If abs_value is specified
    if abs_value == True:
        b = np.abs(b)
        g = np.abs(g)
        r = np.abs(r)

    #merging color channels after filter application
    img = cv.merge((r,g,b))
    
    if abs_value == True:
        N = 256
    else:
        N = 512-1
        
    N = N // downsample

    histr = np.zeros(shape=(N,1), dtype=np.float32)

    for channel in range(3):
        #calculating the histogram
        if abs_value == True:
            histr += cv.calcHist([img],[channel],None,[N],[0,255])
        else:
            histr += cv.calcHist([img],[channel],None,[N],[-255,255])

    #normalized histogram (# norm_histr = histr / histr[0])
    norm_histr = histr/np.max(histr)
    
    return img_norm_hist3d_feature_vector, norm_histr

def read_image(image_path, type='normal'):
    if type == 'normal':
        img = cv.imread(image_path)
        b,g,r = cv.split(img)
        img = cv.merge([r,g,b])
    elif type == 'gray':
        img = cv.imread(image_path, 0)
        
    return img

#defining list of images
images = []

minimum = 2048

####################################### Getting normalized histograms ################################## 
#Iterating recursively over images inside the desired path to get image histograms.
for root, directories, filenames in os.walk(PATH_DIR):
    for filename in filenames:
        #collecting features for the current image.
        image = []
        file = os.path.join(root,filename)

        if file.endswith(".png") or file.endswith(".jpg"):
            #Excluding 38 images with .gif extension(listed in lista_images_tipo_gif_figuras_anotadas.txt)
            #getting root directory and filename for each image and append to features.
            image.append(root)
            image.append(filename)

            #getting original image and his histogram
            img_norm_hist3d_feature_vector, norm_histr = get_histogram(file, True)
            
            #append histr to image list
            image.append(np.array_str(img_norm_hist3d_feature_vector))
            image.append(np.array_str(norm_histr.reshape(1,-1)))
            
            #getting the FFT of the image.
            x_medio = 100
            y_medio = 100
            img = read_image(root + "/" + filename, 'gray')
            img = cv.resize(img, (x_medio, y_medio))
            fft = np.fft.fft2(img)
            
            image.append(fft.real.reshape(1,-1))
            image.append(fft.imag.reshape(1,-1))
            
            #Generating sift descriptors
            sift = cv.xfeatures2d.SIFT_create()
            kp, des = sift.detectAndCompute(img,None)
            #Getting only the first 16 SIFT descriptors
            des = des[:16]
            #des = des.reshape(des.shape[0]*des.shape[1],1)
            image.append(np.array_str(des.reshape(1,-1)))
            
            images.append(image)
                        
####################################### Getting the missing features ##################################            

#Converting images list into a dataframe in order to process each dir or subdir separately.
labels = ['directory', 'filename', 'img_norm_hist3d', 'norm_hist', 'FFTReal','FFTImag','SIFT']
pd_images = pd.DataFrame.from_records(images, columns=labels)

#adding the other labels with blank values
pd_images = pd_images.reindex(columns = labels)

print('before save to csv')

#Saving dataframe to csv
pd_images.to_csv("accio_my_image_dataset_5.csv", index=False)

print("Done")
# Out:
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-380.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2910.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-716.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2804.png
# image_dataset_5/Fotos-Pessoas/BGP V.12 N.2-44.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-726.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-222.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-724.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-786.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-718.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-405.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2609.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2810.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-691.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2806.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2724.png
# image_dataset_5/Fotos-Pessoas/BGP V.12 N.2-2065.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-580.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-865.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-241.png
# image_dataset_5/Fotos-Pessoas/BGP V.19 N.1-2-709.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2098.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2520.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-378.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-751.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-720.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-234.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2386.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2016.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-492.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-496.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-692.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2608.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-364.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2521.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2605.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-686.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-128.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-132.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-372.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-694.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-436.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2394.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-148.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-370.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-484.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-243.png
# image_dataset_5/Fotos-Pessoas/BGP V.12 N.2-2145.png
# image_dataset_5/Fotos-Pessoas/BGP V.12 N.2-2200.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-332.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2094.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-126.png
# image_dataset_5/Fotos-Pessoas/BGP V.12 N.1-1377.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-334.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-689.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-866.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-411.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2384.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-414.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2911.png
# image_dataset_5/Fotos-Pessoas/BGP V.13 N.1-115.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-696.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-365.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2604.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2511.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2728.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-374.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-224.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2524.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-300.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2915.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-403.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-434.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-490.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2721.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2515.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-137.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2517.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-502.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-575.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2019.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-366.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2811.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-482.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2395.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-743.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-579.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-688.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-418.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2390.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-787.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2092.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-135.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-139.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2099.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-488.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-518.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2391.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-220.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2809.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-554.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-141.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-576.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2805.png
# image_dataset_5/Fotos-Pessoas/BGP V.13 N.2-239.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2022.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2814.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2381.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-220.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2023.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2914.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2093.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-562.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2387.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2909.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-688.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-236.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-134.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-3125.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-690.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-230.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2723.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-435.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2908.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2722.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-536.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2385.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2727.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2510.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-287.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-788.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-417.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2018.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-556.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2017.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2091.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-150.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-433.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-654.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-745.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2514.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-288.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-650.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-500.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2516.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-537.png
# image_dataset_5/Fotos-Pessoas/BGP V.13 N.1-241.png
# image_dataset_5/Fotos-Pessoas/BGP V.18 N.2-146.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-779.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2024.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2097.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-749.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-304.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-122.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-498.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-416.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-4297.png
# image_dataset_5/Fotos-Pessoas/BGP V.22 N.1-652.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.1-538.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2816.png
# image_dataset_5/Fotos-Pessoas/BGP V.20 N.1-2-2815.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-456.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-302.png
# image_dataset_5/Fotos-Pessoas/BGP V.21 N.2-409.png
# before save to csv
# Done
